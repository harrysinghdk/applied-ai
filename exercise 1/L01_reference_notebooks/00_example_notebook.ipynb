# %% [markdown]
# %% [markdown]<br>
# # Jupyter notebook example<br>
# file shows how to write python files in VSCode that can be exported to a jupyter notebook<br>
# note that different .py <=> .ipynb tools will use different comment styles. **Always check the documentation**<br>
# <br>
# - VSCode integration for jupyter notebooks https://code.visualstudio.com/docs/datascience/jupyter-notebooks<br>
# - VSCode interactive window                https://code.visualstudio.com/docs/python/jupyter-support-py    <br>
# - alternative if you're not using VSCode   https://pypi.org/project/p2j/                                   <br>
# - Colab "quick start"                      https://colab.research.google.com/#scrollTo=-Rh3-Vt9Nev9<br>
# <br>
# **NB:** I didn't manage to find a good and practical Colab guide about how to use colab, just marketing list of features<br>
#         and lots of superfluous start. It should be quite intuitive if you ever used python and other IDEs, and we will also<br>
#         cover some usefult tips in class. If you have any additional problems, reach out and we can look at it togheter.<br>
# <br>
# If you DO find a good, comprehensive and precise guide, please let me know.

# %% [markdown]
# %%<br>
# ^^^ the `# %%` sequence marks the start of a new code cell

# %% [markdown]
# some code

# %%
a = list(range(1000))

# %% [markdown]
# if the very last statement of a code cell evaluates to a value, the notebook will pretty print it

# %%
a

# %% [markdown]
# %% [markdown]<br>
# ^^^ the `# %% [markdown]` sequence marks the start of a markdown cell<br>
# <br>
# in an actualy notebook, you wouldn't need to start the lines with `#`, but of course in a `.py` file they would create problems.<br>
# utilities that do conversion of `.py` files into ntoebook files will automatically remove these extra comments<br>
# <br>
# ## You can use most markdown syntax in here!<br>
# Emphasys on **most**<br>
# <br>
# markdown tables, for example, will work on VScode interactive tab but NOT in exported .ipynb files<br>
# | foo | bar    |<br>
# | --- | ------ |<br>
# | baz | foobar |

# %% [markdown]
# %%

# %% [markdown]
# some other code

# %%
b = a[10:20]
